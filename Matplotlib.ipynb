# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot([1,2,3,4],[10,20,30,40])
plt.show()

# %%
plt.plot([1,2,3,4],[10,20,30,40])
plt.title("Sales Plot")
plt.xlabel("Month")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.figure(figsize=(15,5))

# %%
plt.plot([1,2,3,4],[100,200,300,400],"g-")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"g--")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"g:")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"g.")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"ro")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"b<")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"r>")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"r^")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"g*")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"gx")

# %%
plt.plot([1,2,3,4],[100,200,300,400],"yD")

# %%
x=np.arange(1,5)
y=x**5
plt.plot([1,2,3,4],[10,20,30,40],"ro",x,y,"g^")
plt.show()

# %%
month=["Jan","Feb","Mar","Apr","May"]
sales=[50,60,55,75,65]
plt.bar(month,sales,color="green")
plt.show()

# %%
plt.barh(month,sales,color="red")
plt.show()
