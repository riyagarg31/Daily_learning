# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bb=data.DataReader(name="BB",data_source="yahoo",start="2009-10-31",end="2015-10-31")

# %%
bb
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2009-10-30  61.529999  58.419998  61.520000  58.730000  21622800  58.730000
# 2009-11-02  57.200001  54.299999  56.849998  55.740002  37434100  55.740002
# 2009-11-03  60.139999  55.380001  55.840000  59.610001  30719500  59.610001
# 2009-11-04  60.459999  57.560001  60.430000  57.610001  19940600  57.610001
# 2009-11-05  59.500000  57.200001  59.080002  57.790001  20333500  57.790001
# ...               ...        ...        ...        ...       ...        ...
# 2015-10-26   7.560000   7.230000   7.280000   7.270000   6307200   7.270000
# 2015-10-27   7.280000   6.990000   7.260000   7.000000   4832400   7.000000
# 2015-10-28   7.280000   6.960000   7.050000   7.190000   4240200   7.190000
# 2015-10-29   7.270000   7.100000   7.170000   7.120000   3042600   7.120000
# 2015-10-30   7.310000   7.090000   7.140000   7.290000   4354000   7.290000
#
# [1511 rows x 6 columns]

# %%
bb.plot(y="Open")

# %%
bb["Close"].plot()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("classic")

# %%
bb["Close"].plot()

# %%
def rank_performance(stock_price):
    if stock_price<10:
        return"poor"
    elif stock_price<=50:
        return "satisfactory"
    else:
        return"stellar"

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind="barh")

# %%
bb["Close"].mean()
# Out:
# 24.587776303370216

# %%
def rank(stock_price):
    if stock_price>=24.587776303370216:
        return"above average"
    else:
        return"below average"

# %%
bb["Close"].apply(rank).value_counts().plot(kind="pie",legend=True)
